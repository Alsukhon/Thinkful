# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from matplotlib.mlab import PCA as mlabPCA
from scipy.stats.mstats import winsorize
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sqlalchemy import create_engine
import warnings
# %matplotlib inline


warnings.filterwarnings('ignore')
sns.set_style("whitegrid")

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'lifeexpectancy'
table_name = 'lifexpectancy'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

lifex = pd.read_sql_query('select * from lifeexpectancy',con=engine)

# no need for an open connection, 
# as we're only doing a single query
engine.dispose()

lifex.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ### Your goal in this challenge is to find the factors that affect the life expectancy. Specifically, you need to find out which factors increase the expected life in the countries and which factors decrease it.

# %% [markdown]
# #### Detect the problems with the data such as missing values and outliers. Are there any nonsense values that seem to be stemmed from the data collection?
#
# - For the missing values, discuss which technique would be the most suitable one in filling out these values.
#
# - Regarding the outliers, discuss their potential effects on your analysis and select an appropriate method to deal with them.

# %%
# Pre-prep
# Strip column titles from whitespace
titles = {k:k.replace(k,k.strip()) for k in lifex.columns}
lifex.rename(columns=titles,inplace=True)

# %% [markdown]
# # Missing Values

# %% [markdown]
# Let's begin by taking a look at missing values and exploring how they came to be:

# %%
print(len(lifex))
lifex.isnull().sum()
# Out:
# 2938
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# Many values seem to be missing from the *Population*, *Hepatitis B*, *GDP* and *Total expenditure* columns, respectively. If these missing values came from rows where countries have existent values for the year before or after, that would be ok and imputation would be easy.
#
# Let's try to check what correlates with each of the 3 columns with most missing values: *Population*, *Hepatitis B*, *GDP* :

# %%
# correlate life expectancy to all variables:
correlation = lifex.corr()
correlation[['Population','Hepatitis B','GDP']]
# Out:
#                                  Population  Hepatitis B       GDP
# Year                               0.016969     0.104333  0.101620
# Life expectancy                   -0.021538     0.256762  0.461455
# Adult Mortality                   -0.013647    -0.162476 -0.296049
# infant deaths                      0.556801    -0.223566 -0.108427
# Alcohol                           -0.035252     0.087549  0.354712
# percentage expenditure            -0.025662     0.016274  0.899373
# Hepatitis B                       -0.123321     1.000000  0.083903
# Measles                            0.265966    -0.120529 -0.076466
# BMI                               -0.072301     0.150380  0.301557
# under-five deaths                  0.544423    -0.233126 -0.112081
# Polio                             -0.038540     0.486171  0.211976
# Total expenditure                 -0.079662     0.058280  0.138364
# Diphtheria                        -0.028444     0.611495  0.200666
# ...

# %% [markdown]
# Nothing seems to be out of the norm; *Population* correlates with nothing other that *infant* and *under-five deaths* significantly. The two can be considered hieararchical since infants are included in under-five deaths and therefore are strongly correlated, and both
# make a factor of population.
#
# *Hepatitis B* correlates with *Diphteria*, which we can correctly guess are existent in countries that lack resources for public health and are living in bad conditions due to a collection of reasons.
#
# *GDP* correlates with *Total expenditure*, which is also expected.
#
# None of these variables correlates with an unexpected variable or is even in the situation that warrants further exploration as to whether any values are missing at random.

# %% [markdown]
# In general, missing data in this dataset will be most suitably filled from rows containing data from **the same country** but for the **previous year**, why? Because a country's values for a given variable are likely to be close when compared for two consecutive years. However, if the values for the first year for each country (i.e, year 2000 here) are missing, then the values of the year after (2001) are most suitable to fill it.
#
# This calls for filling the values of the first year using forward fill first, and then filling the rest of the dataset with backward fill, let's do that here:

# %%
lifex = lifex.sort_values(by=['Country','Year'])
lifex.head()
# Out:
#         Country  Year      Status  Life expectancy  Adult Mortality  \
# 15  Afghanistan  2000  Developing             54.8            321.0
# 14  Afghanistan  2001  Developing             55.3            316.0
# 13  Afghanistan  2002  Developing             56.2              3.0
# 12  Afghanistan  2003  Developing             56.7            295.0
# 11  Afghanistan  2004  Developing             57.0            293.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 15             88     0.01               10.424960         62.0     6532  ...
# 14             88     0.01               10.574728         63.0     8762  ...
# 13             88     0.01               16.887351         64.0     2486  ...
# 12             87     0.01               11.089053         65.0      798  ...
# 11             87     0.02               15.296066         67.0      466  ...
#
#     Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
# How many years worth of data per country?
np.unique(lifex['Year'])
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
# For each country, fill row of first year using forward fill
index_list = [lifex[lifex['Country']==country].index[0] for country in np.unique(lifex['Country'])] #if lifex.loc[index].isnull().sum() != 0]

for index in index_list:
    if lifex.loc[index].isnull().sum() != 0:
        lifex.loc[index].fillna(method='ffill',inplace=True)
print(lifex.isnull().sum())
# Now fill the rest of the dataset using backward fill
lifex.fillna(method='backfill',inplace=True)
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# # Outliers

# %% [markdown]
# Before going into outliers, and since we'll be starting with individual plots for variables of interest, let's see which variables correlate the most with *Life expectancy*:

# %%
# Re-use the correlation variable
correlation = lifex.corr()
correlation = correlation.sort_values(by=['Life expectancy'], ascending=False)

correlation[['Life expectancy']]
# Out:
#                                  Life expectancy
# Life expectancy                         1.000000
# Schooling                               0.681763
# Income composition of resources         0.670519
# BMI                                     0.545069
# Diphtheria                              0.476122
# Polio                                   0.461525
# GDP                                     0.433047
# percentage expenditure                  0.381277
# Alcohol                                 0.367903
# Hepatitis B                             0.262452
# Total expenditure                       0.190819
# Year                                    0.168374
# Population                             -0.006870
# Measles                                -0.157127
# infant deaths                          -0.195983
# under-five deaths                      -0.221901
# thinness 5-9 years                     -0.454309
# thinness  1-19 years                   -0.459941
# ...

# %% [markdown]
# Schooling, Income composition of resources, Adult Mortality and HIV/AIDS seem to correlate the strongest with with the Life expectancy column, respectively.
#
# - Schooling and Income composition of resources increase with Life Expectancy for countries.
#
# - Adult Mortality, HIV/AIDS have an understandable negative correlation with Life Expectancy.

# %%
# Plot each of the 4 variables
plt.boxplot(lifex['Schooling'])
plt.title('Schooling')
plt.show()
plt.boxplot(lifex['Income composition of resources'])
plt.title('Income composition of resources')
plt.show()
plt.boxplot(lifex['Adult Mortality'])
plt.title('Adult Mortality')
plt.show()
plt.boxplot(lifex['HIV/AIDS'])
plt.title('HIV/AIDS')
plt.show()

# %% [markdown]
# Adult mortality and HIV both have many outliers. We will winsorize both of them in order to get a smaller range:

# %%
# Perform winsorization on variables with outliers
lifex['Adult Mortality'] = winsorize(lifex['Adult Mortality'],limits=[0.05,.09]) 
lifex['HIV/AIDS'] = winsorize(lifex['HIV/AIDS'],limits=[0.05,.20])

# %% [markdown]
# Let's take a look again:

# %%
# Re-plot variables with outliers
plt.boxplot(lifex['Adult Mortality'])
plt.title('Adult Mortality')
plt.show()
plt.boxplot(lifex['HIV/AIDS'])
plt.title('HIV/AIDS')
plt.show()

# %% [markdown]
# Poof! No outliers.

# %%
lifex.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2938.000000      2938.000000    2938.000000
# mean   2007.518720        69.217325         4.721478           -inf
# std       4.613841         9.524432         0.949624            NaN
# min    2000.000000        36.300000         2.564949           -inf
# 25%    2004.000000        63.100000         4.304065           -inf
# 50%    2008.000000        72.050000         4.969813       1.098612
# 75%    2012.000000        75.700000         5.429346       3.091042
# max    2015.000000        89.000000         5.840642       7.495542
#
#            Alcohol  percentage expenditure  Hepatitis B      Measles  \
# count  2937.000000             2938.000000  2938.000000  2938.000000
# mean      4.627184                    -inf    74.845133         -inf
# std       4.064449                     NaN    29.398675          NaN
# min       0.010000                    -inf     1.000000         -inf
# ...

# %% [markdown]
# # Univariate & Multivariate Analysis

# %% [markdown]
# We will perform univariate analysis for our 5 most important variables, exploring their values and variance, as well as plotting their distribution.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Schooling

# %%
# Re-use the correlation variable
correlation = lifex.corr()
correlation = correlation.sort_values(by=['Schooling'], ascending=False)

correlation[['Schooling']]
# Out:
#                                  Schooling
# Schooling                         1.000000
# Income composition of resources   0.803874
# Life expectancy                   0.681763
# percentage expenditure            0.602112
# GDP                               0.566852
# BMI                               0.462554
# Alcohol                           0.452774
# Polio                             0.393024
# Diphtheria                        0.392231
# Total expenditure                 0.216921
# Year                              0.198794
# Hepatitis B                       0.195513
# Population                       -0.027888
# Measles                          -0.318879
# Adult Mortality                  -0.318952
# thinness 5-9 years               -0.403428
# thinness  1-19 years             -0.412849
# infant deaths                    -0.420973
# under-five deaths                -0.468652
# HIV/AIDS                         -0.517432

# %% [markdown]
# It seems like *Schooling* has strong correlation with *Income composition of resources*. This is normally explained by countries that are doing better financially focusing on their education systems. However, this may reduce the quality of our model, because one of these variables can, in large part, describe the other.
#
# Schooling also correlates with other variables that describe a country's financial situation, which corroborates the situation between *Schooling* and *Income composition of resources*.

# %%
lifex['Schooling'].describe()
# Out:
# count    2938.000000
# mean       12.124438
# std         3.341817
# min         0.000000
# 25%        10.300000
# 50%        12.500000
# 75%        14.300000
# max        20.700000
# Name: Schooling, dtype: float64

# %% [markdown]
# The range of values for the *Schooling* variable isn't really that huge, especially after dealing with missing values and outliers earlier.

# %% [markdown]
# ### Income composition of resources

# %%
# Re-use the correlation variable
correlation = lifex.corr()
correlation = correlation.sort_values(by=['Income composition of resources'], ascending=False)

correlation[['Income composition of resources']]
# Out:
#                                  Income composition of resources
# Income composition of resources                         1.000000
# Schooling                                               0.803874
# Life expectancy                                         0.670519
# percentage expenditure                                  0.577658
# GDP                                                     0.553750
# BMI                                                     0.444939
# Alcohol                                                 0.392805
# Diphtheria                                              0.378632
# Polio                                                   0.368601
# Year                                                    0.231302
# Hepatitis B                                             0.201286
# Total expenditure                                       0.150135
# Population                                              0.008004
# ...

# %% [markdown]
# Correlation for *Income composition of resources* does not any additional information other than what has been described in the univariate analysis for *Schooling*.

# %%
lifex['Income composition of resources'].describe()
# Out:
# count    2938.000000
# mean        0.635130
# std         0.208359
# min         0.000000
# 25%         0.503250
# 50%         0.686000
# 75%         0.782000
# max         0.948000
# Name: Income composition of resources, dtype: float64

# %% [markdown]
# Income composition of resources seems to variate by %20 from country to country usually.

# %% [markdown]
# ### Adult Mortality

# %%
# Re-use the correlation variable
correlation = lifex.corr()
correlation = correlation.sort_values(by=['Adult Mortality'], ascending=False)

correlation[['Adult Mortality']]
# Out:
#                                  Adult Mortality
# Adult Mortality                         1.000000
# HIV/AIDS                                0.365923
# under-five deaths                       0.241813
# thinness 5-9 years                      0.221652
# infant deaths                           0.220487
# thinness  1-19 years                    0.211282
# Measles                                 0.140263
# Population                             -0.020304
# Year                                   -0.023914
# Hepatitis B                            -0.086860
# Total expenditure                      -0.125968
# Alcohol                                -0.145479
# Polio                                  -0.196335
# Diphtheria                             -0.197114
# GDP                                    -0.277821
# BMI                                    -0.281090
# percentage expenditure                 -0.282935
# Income composition of resources        -0.312268
# ...

# %% [markdown]
# Adult Mortality seems to have no strong correlation with any other variable, this makes it a good option to choose. It is mentionable that its correlation with Life expectancy has dropped after winsorization. Still, its lack of correlation with other variables may bring a higher value of information to the model.

# %%
lifex['Adult Mortality'].describe()
# Out:
# count    2938.000000
# mean        4.721478
# std         0.949624
# min         2.564949
# 25%         4.304065
# 50%         4.969813
# 75%         5.429346
# max         5.840642
# Name: Adult Mortality, dtype: float64

# %% [markdown]
# It seems that Adult Mortability is relatively stable globally after data per-preparation. The standard deviation is less than 20% of the range of the variable.

# %% [markdown]
# Now to take a look at the distribution of each variable:

# %%
plt.figure(figsize=(18,15))

# histograms of the original data
plt.subplot(3, 3, 1)
plt.hist(lifex["Adult Mortality"])
plt.title("Adult Mortality")

plt.subplot(3, 3, 2)
plt.hist(np.log(lifex["HIV/AIDS"]))
plt.title("HIV")

plt.subplot(3, 3, 3)
plt.hist(lifex["Income composition of resources"])
plt.title("Income")

# histograms of the winsorized data
plt.subplot(3, 3, 4)
plt.hist(lifex["Schooling"])
plt.title("Schooling")

plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# In our multivariate analysis, we'll explore the relationship between each of our chosen variable, and the target variable.
#
# Also, we will be checking out the correlation throughout the dataset using a heatmap.

# %% [markdown]
# We will start by plotting a scatter plot for *Schooling* and *Life expectancy*:

# %%
plt.scatter(lifex['Life expectancy'] ,lifex['Schooling'], )
plt.show()

# %% [markdown]
# How about the same plot for *Income composition of resources*?

# %%
plt.scatter(lifex['Life expectancy'] ,lifex['Income composition of resources'], )
plt.show()

# %% [markdown]
# Out of the two, Income composition of resources seems to correlate better with Life expectancy. Therefore we will be choosing it instead of the Schooling variable. Any of the two can be chosen because in reality, either of the two can explain the existence of the other.

# %%
# make the correlation matrices.
corr_mat_lifex = lifex.corr()


# heatmaps are a great way to get 
# a quick visual read on a big correlation matrix.

plt.figure(figsize=(18,15))

plt.plot(1,1)
# draw the heatmap using seaborn.
sns.heatmap(corr_mat_lifex, square=True, annot=True, linewidths=.5)
plt.title("correlation matrix (Youtube)")

plt.show()

# try to match the correlation numbers 
# to the scatterplots above to get a 
# sense of what each magnitude of 
# correlation can look like.

# %% [markdown]
# In the feature engineering step, we need to select a suite of variables that we think would be ideal in the modeling phase. More concretely, we may discard some variables that are very correlated with the other ones or the variables that we think are irrelevant to life expectancy.
#
# ## Feature Engineering

# %%
# Get rid of categorical columns
lifex_pca = lifex.drop(columns=['Country','Status'])
lifex_pca = lifex_pca.replace([np.inf, -np.inf], np.nan).dropna()

# PCA 
X = StandardScaler().fit_transform(lifex_pca.dropna())
sklearn_pca = PCA(n_components=2,svd_solver='full')
Y_sklearn = sklearn_pca.fit_transform(X)
# Out:
# [[-3.5576183  -1.57482351]
#  [-3.31566584 -1.30832787]
#  [-3.31116416  0.59014317]
#  ...
#  [-2.01234086 -0.54879228]
#  [-2.68261741 -1.00731232]
#  [-1.79965826 -0.48321701]]

# %%
Y_sklearn[:, 0] #pca1
Y_sklearn[:, 1] #pca2
# Out:
# array([-1.57482351, -1.30832787,  0.59014317, ..., -0.54879228,
#        -1.00731232, -0.48321701])

# %%
len(sklearn_pca.components_)
# Out:
# 2

# %% [markdown]
# Summarize your findings. One of the most important skills of a data scientist is to convey ideas and findings to nontechnical people using understandable language. In this regard, one of the most effective ways to communicate your ideas is to do it using effective visualization.

# %% [markdown]
# ### PCA1 (First PCA component)

# %%
# plt.scatter(lifex['Life expectancy'][:len(Y_sklearn[:, 0])],Y_sklearn[:, 0])
temp_df = pd.DataFrame({'lifex':lifex_pca['Life expectancy'],'pca1':Y_sklearn[:, 0],'pca2':Y_sklearn[:, 1]})
# temp_df
sns.set(style="darkgrid")

g = sns.jointplot('lifex', "pca1", data=temp_df, kind="reg", color="m", height=7)

# %% [markdown]
# This scatterplot shows a clear correlation between pca1 and life expectancy. For example, if pca1 was at 0, our model would guess life expectancy is between 60 to 70 and can be less.
#
# Most importantly, pca1 shows more explainability for life expectancy than other variables that came with the dataset. It would be much more efficient if it was included in a model instead of, say, the Schooling variable.

# %% [markdown]
# ### PCA2 (Second PCA component)

# %%
sns.set(style="darkgrid")

g = sns.jointplot('lifex', 'pca2', data=temp_df, kind="reg", color="m", height=7)

# %% [markdown]
# Pca1 also has the ability to explain life expectancy in a clear manner. It is noticeable that pca2 follows a normal distribution very closely. This makes pca2 a variable that is fit for using in prediciton models, as many models assume normal distribution of features.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Having dealt with missing values, outliers, and feature engineering for this dataset, we can conclude with certainty that pre-preparation for values can drastically change variable -or *features*-, therefore improving models by improving their inputs.
#
# Without a doubt, hyperparameter optimization can decide on the way these models process inputs, but we are yet to see the magnitude of increase of accuracy with the enhancement of both, and that by itself depends on the model, the algorithm, and the available hyperparameters involved.
